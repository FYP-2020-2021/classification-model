# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16160272307814550250, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14674281152
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 5596870904311398114
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
# !git clone https://github.com/nishkalavallabhi/OneStopEnglishCorpus
# !mv OneStopEnglishCorpus/Texts-SeparatedByReadingLevel/Int-Txt/Int-Txt/ OneStopEnglishCorpus/Processed-AllLevels-AllFiles/
# Out:
# Cloning into 'OneStopEnglishCorpus'...
# remote: Enumerating objects: 3074, done.
# remote: Total 3074 (delta 0), reused 0 (delta 0), pack-reused 3074
# Receiving objects: 100% (3074/3074), 23.50 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (1143/1143), done.
# Checking out files: 100% (2656/2656), done.

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/FIT3161/aclImdb_v1.tar.gz ./
# !tar -xvf aclImdb_v1.tar.gz
# Out:
# ^C
# tar: This does not look like a tar archive
#
# gzip: stdin: unexpected end of file
# tar: Child returned status 1
# tar: Error is not recoverable: exiting now

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/data_manager.py ./
# !cp -r /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/models/ ./
# !cp /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/train.py ./

# %%
# !python3 data_manager.py /content/OneStopEnglishCorpus/Texts-SeparatedByReadingLevel -v

# %%
# !cp data_manager.py /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/
# !cp -r ./models/ /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/
# !cp train.py /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !python3 train.py OneStopEnglishCorpus/Texts-SeparatedByReadingLevel\
                -v\
                --arch bigruattention\
                --encoding utf8\
                --epochs 50 -b 8\
                --lr 0.0001\
                --train-ratio 0.9\
                --l2-regularizer-factor=0.3\
                --dropout=0.5\
                --model-dir /content/drive/MyDrive/Colab\ Notebooks/FIT3161/Implementation/checkpoints/
# Out:
# 2021-03-03 15:27:03.605985: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#
# Sample questions...
#
# intermediate
# himalayan lakes, spacewalks and the us presidential campaign helped scott kelly stay sane during his 340 days in space, the astronaut told journalists after he landed back on earth from a record-breaking mission.
# it seemed like i lived there forever, kelly said.
# he had been on several previous missions but said that his biggest surprise was simply how long this one felt.
# maybe, occasionally, you do go bananas, he said.
# kelly and a russian colleague, mikhail kornienko, spent nearly a year on the international space station (iss) in order to study the effects of weightlessness, radiation and the cramped conditions of space ight on humans.
# ...
